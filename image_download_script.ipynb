# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import joblib
import numpy as np
import pandas as pd
import re
import os
import time

from PIL import Image, ImageFilter
import requests

pd.set_option('max_colwidth', 100)
pd.options.display.max_rows = 500
pd.options.display.max_columns = 500

# %%
# https://machinelearningmastery.com/how-to-load-and-manipulate-images-for-deep-learning-in-python-with-pil-pillow/

#https://realpython.com/python-requests/#timeouts

# %%
#Import cleaned dataframe.
vehicle=joblib.load('vehicleClean.joblib')

# %%
vehicle.head(2)
# Out:
#                                                                                    URL_Vehicle  \
# 1              https://austin.craigslist.org/cto/d/red-rock-2006-ford-focus-se/7022331083.html
# 2  https://austin.craigslist.org/cto/d/marble-falls-04-ford-f450-service-truck/7022347414.html
#
#                          Title Location  Year  Year_in_Title  Odometer  \
# 1           2006 Ford Focus SE   austin  2006            NaN       NaN
# 2  ‘04 FORD F450 SERVICE TRUCK   austin  2004            NaN  100000.0
#
#               RawMake  Make  Model  Trim Seller   Price          SubLoc  \
# 1  2006 ford focus se  ford  focus    se  owner  3000.0   (Cedar Creek)
# 2      2004 ford f450  ford  f-450  None  owner  8950.0  (Marble Falls)
#
#                                                                                                   Body  \
# 1  [\n        , \n2006 Ford Focus in great mechanical condition-AC/Heater work great-Tires have som...
# 2  [\n        , \nThis is a really nice dependable truck that we’ve been using daily for over a yea...
#
#                                                                                       AttribDictionary  \
# 1  {'0': '<span><b>2006 Ford Focus SE</b></span>', '1': '<span>fuel: <b>gas</b></span>', '2': '<spa...
# 2  {'0': '<span><b>2004 FORD F450</b></span>', '1': '<span>condition: <b>excellent</b></span>', '2'...
#
#                                                                                        ImageDictionary  \
# 1  {'0': 'https://images.craigslist.org/00n0n_dXTq6r46TL4_600x450.jpg', '1': 'https://images.craigs...
# 2  {'0': 'https://images.craigslist.org/01717_30HqNTmEVww_600x450.jpg', '1': 'https://images.craigs...
#
#     VehicleID  VIN  LN_Price  Model_Trim Model_Seller Trim_Seller
# 1  7022331083  NaN  8.006701    focus_se  focus_owner    se_owner
# 2  7022347414  NaN  9.099521  f-450_None  f-450_owner  None_owner

# %%
vehicle[['ImageDictionary']].head(2)
# Out:
#                                                                                        ImageDictionary
# 1  {'0': 'https://images.craigslist.org/00n0n_dXTq6r46TL4_600x450.jpg', '1': 'https://images.craigs...
# 2  {'0': 'https://images.craigslist.org/01717_30HqNTmEVww_600x450.jpg', '1': 'https://images.craigs...

# %%
#Insert VehicleID from URL_Vehicle
idList=[]
for idx in vehicle.index:
    m = re.search('/(\d+)\.html', vehicle.loc[idx, 'URL_Vehicle']) #re.search(pattern, string) gets first match
    if m is not None:
        idList.append(m.group(1).lower())
    else:
        print('Missing Make/Model index:', idx)
        idList.append('None')
                 
vehicle['VehicleID'] = idList

# %%
vehicle.head(2)
# Out:
#                                                                                    URL_Vehicle  \
# 1              https://austin.craigslist.org/cto/d/red-rock-2006-ford-focus-se/7022331083.html
# 2  https://austin.craigslist.org/cto/d/marble-falls-04-ford-f450-service-truck/7022347414.html
#
#                          Title Location  Year  Year_in_Title  Odometer  \
# 1           2006 Ford Focus SE   austin  2006            NaN       NaN
# 2  ‘04 FORD F450 SERVICE TRUCK   austin  2004            NaN  100000.0
#
#               RawMake  Make  Model  Trim Seller   Price          SubLoc  \
# 1  2006 ford focus se  ford  focus    se  owner  3000.0   (Cedar Creek)
# 2      2004 ford f450  ford  f-450  None  owner  8950.0  (Marble Falls)
#
#                                                                                                   Body  \
# 1  [\n        , \n2006 Ford Focus in great mechanical condition-AC/Heater work great-Tires have som...
# 2  [\n        , \nThis is a really nice dependable truck that we’ve been using daily for over a yea...
#
#                                                                                       AttribDictionary  \
# 1  {'0': '<span><b>2006 Ford Focus SE</b></span>', '1': '<span>fuel: <b>gas</b></span>', '2': '<spa...
# 2  {'0': '<span><b>2004 FORD F450</b></span>', '1': '<span>condition: <b>excellent</b></span>', '2'...
#
#                                                                                        ImageDictionary  \
# 1  {'0': 'https://images.craigslist.org/00n0n_dXTq6r46TL4_600x450.jpg', '1': 'https://images.craigs...
# 2  {'0': 'https://images.craigslist.org/01717_30HqNTmEVww_600x450.jpg', '1': 'https://images.craigs...
#
#     VehicleID  VIN  LN_Price  Model_Trim Model_Seller Trim_Seller
# 1  7022331083  NaN  8.006701    focus_se  focus_owner    se_owner
# 2  7022347414  NaN  9.099521  f-450_None  f-450_owner  None_owner

# %%
#Extract images to imDict: {'VehicleID': {'EntryNum' : 'imFName'}
imDict={}
for idx in vehicle.index:
    vehID = vehicle.loc[idx, 'VehicleID']
    imDict[vehID]={}
    for k in vehicle.loc[idx, 'ImageDictionary'].keys():
        m = re.search('org/(\S+)\.jpg', vehicle.loc[idx, 'ImageDictionary'][str(k)]) #re.search(pattern, string) gets first match    
        imDict[vehID][k] = m.group(1)

# %%
joblib.dump(imDict, 'imDict.joblib', compress=0)
print(len(vehicle))
print(len(imDict))
# Out:
# 7343
# 7343

# %% [markdown]
# ###  Download images using imDict

# %%
#Fetch URLs from imDict.  Open URL, get image filename, and save to disk.
#Save to: Z:\DATA_SCIENCE\car_images\{VehicleID}\{imFName}

vehCount = 0
imCount = 0
errorDict={}

for vehID in imDict.keys():  #get top key--vehID
    vehCount += 1
    try:
        os.mkdir(f'Z:/DATA_SCIENCE/car_images/{vehID}')     #make vehicleID folder
    except:
        print(f'Error making directory.  Directory {vehID} exists.')
        continue
    short_sleep_sec = np.random.randint(low=1, high=3)
    time.sleep(short_sleep_sec)
    
    for val in imDict[vehID].values():  #get second level value--the image name
        imCount += 1
        URL = f'https://images.craigslist.org/{val}.jpg'
        
        #Sleep every 450 images
        if imCount % 450 == 0:
            sleep_sec = np.random.randint(low=61, high=140)
            print(f'Sleeping...  Current imCount:', imCount)
            time.sleep(sleep_sec)        
          
        try:
            #Open image. Timemout is: (connect timeout, read timeout) in seconds.
            im = Image.open(requests.get(URL, stream=True, timeout=(5.15, 9.5)).raw)    
        except requests.exceptions.Timeout:
            print(f'Timout error.', vehID, val)
            errorDict[vehID] = (val,'timeout_error')
            joblib.dump(errorDict, 'errorDict.joblib', compress=0)
        except:
            print(f'Non-timeout error.', vehID, val)
            errorDict[vehID] = (val,'non-timeout_error')
            joblib.dump(errorDict, 'errorDict.joblib', compress=0)
            
        imFName = re.search('org/(\S+)\.jpg', URL).group(1) + '.png'    #get image filename from URL and add png.
        try:
            im.save(f'Z:/DATA_SCIENCE/car_images/{vehID}/{imFName}', format='PNG')  #save im to path
        except:
            print('Saving error.')
        
print('VehicleID vehCount:', vehCount)
# Out:
# Error making directory.  Directory 7022331083 exists.
# Error making directory.  Directory 7022347414 exists.
# Error making directory.  Directory 7022290197 exists.
# Error making directory.  Directory 7022393859 exists.
# Error making directory.  Directory 7022376582 exists.
# Error making directory.  Directory 7021342410 exists.
# Error making directory.  Directory 7021388137 exists.
# Error making directory.  Directory 7021390767 exists.
# Error making directory.  Directory 7021413592 exists.
# Error making directory.  Directory 7021416075 exists.
# Error making directory.  Directory 7021443320 exists.
# Error making directory.  Directory 7021454505 exists.
# Error making directory.  Directory 7021477786 exists.
# Error making directory.  Directory 7021498834 exists.
# Error making directory.  Directory 7021535769 exists.
# Error making directory.  Directory 7021643460 exists.
# Error making directory.  Directory 7021672366 exists.
# Error making directory.  Directory 7021684777 exists.
# Error making directory.  Directory 7021693407 exists.
# Error making directory.  Directory 7021722430 exists.
# Error making directory.  Directory 7021724709 exists.
# Error making directory.  Directory 7021724534 exists.
# Error making directory.  Directory 7021724744 exists.
# Error making directory.  Directory 7021750695 exists.
# Error making directory.  Directory 7021773163 exists.
# Error making directory.  Directory 7021795408 exists.
# Error making directory.  Directory 7021796842 exists.
# Error making directory.  Directory 7021808180 exists.
# Error making directory.  Directory 7021816120 exists.
# Error making directory.  Directory 7021837877 exists.
# Error making directory.  Directory 7021818812 exists.
# Error making directory.  Directory 7020573588 exists.
# Error making directory.  Directory 7020590820 exists.
# Error making directory.  Directory 7020574802 exists.
# Error making directory.  Directory 7020586734 exists.
# Error making directory.  Directory 7020612440 exists.
# Error making directory.  Directory 7020050879 exists.
# Error making directory.  Directory 7020079045 exists.
# Error making directory.  Directory 7020089264 exists.
# Error making directory.  Directory 7020095655 exists.
# Error making directory.  Directory 7020096815 exists.
# Error making directory.  Directory 7020096851 exists.
# Error making directory.  Directory 7020096861 exists.
# Error making directory.  Directory 7020104104 exists.
# Error making directory.  Directory 7020176069 exists.
# Error making directory.  Directory 7020192607 exists.
# Error making directory.  Directory 7020192612 exists.
# Error making directory.  Directory 7020192610 exists.
# Error making directory.  Directory 7020217059 exists.
# Error making directory.  Directory 7020226078 exists.
# Error making directory.  Directory 7020234865 exists.
# Error making directory.  Directory 7020240233 exists.
# Error making directory.  Directory 7020266961 exists.
# Error making directory.  Directory 7020312262 exists.
# Error making directory.  Directory 7020313476 exists.
# Error making directory.  Directory 7019458526 exists.
# Error making directory.  Directory 7019466046 exists.
# Error making directory.  Directory 7019493622 exists.
# Error making directory.  Directory 7019099198 exists.
# Error making directory.  Directory 7019107755 exists.
# Error making directory.  Directory 7018737027 exists.
# Error making directory.  Directory 7018771365 exists.
# Error making directory.  Directory 7018678591 exists.
# Error making directory.  Directory 7018774711 exists.
# Error making directory.  Directory 7018786993 exists.
# Error making directory.  Directory 7018812497 exists.
# Error making directory.  Directory 7018812485 exists.
# Error making directory.  Directory 7018812496 exists.
# Error making directory.  Directory 7018844036 exists.
# Error making directory.  Directory 7018853111 exists.
# Error making directory.  Directory 7018854755 exists.
# Error making directory.  Directory 7018856175 exists.
# Error making directory.  Directory 7018861319 exists.
# Error making directory.  Directory 7018884274 exists.
# Error making directory.  Directory 7018888708 exists.
# Error making directory.  Directory 7018932140 exists.
# Error making directory.  Directory 7018933559 exists.
# Error making directory.  Directory 7018955492 exists.
# Error making directory.  Directory 7018983923 exists.
# Error making directory.  Directory 7018983966 exists.
# Error making directory.  Directory 7018984037 exists.
# Error making directory.  Directory 7018984036 exists.
# Error making directory.  Directory 7018984272 exists.
# Error making directory.  Directory 7018984784 exists.
# Error making directory.  Directory 7018985130 exists.
# Error making directory.  Directory 7018998045 exists.
# Error making directory.  Directory 7017812079 exists.
# Error making directory.  Directory 7017812213 exists.
# Error making directory.  Directory 7017825683 exists.
# Error making directory.  Directory 7017848571 exists.
# Error making directory.  Directory 7017872102 exists.
# Error making directory.  Directory 7017299168 exists.
# Error making directory.  Directory 7017306017 exists.
# Error making directory.  Directory 7017371503 exists.
# Error making directory.  Directory 7017380077 exists.
# Error making directory.  Directory 7017413108 exists.
# Error making directory.  Directory 7017466694 exists.
# Error making directory.  Directory 7017494100 exists.
# Error making directory.  Directory 7017524680 exists.
# Error making directory.  Directory 7017553220 exists.
# Error making directory.  Directory 7017557218 exists.
# Error making directory.  Directory 7017672226 exists.
# Error making directory.  Directory 7017673326 exists.
# Error making directory.  Directory 7017699281 exists.
# Error making directory.  Directory 7017715731 exists.
# Error making directory.  Directory 7017717862 exists.
# Error making directory.  Directory 7017718930 exists.
# Error making directory.  Directory 7016962116 exists.
# Error making directory.  Directory 7016962110 exists.
# Error making directory.  Directory 7016971790 exists.
# Error making directory.  Directory 7017041044 exists.
# Error making directory.  Directory 7017064225 exists.
# Error making directory.  Directory 7017246450 exists.
# Error making directory.  Directory 7016156613 exists.
# Error making directory.  Directory 7016169506 exists.
# Error making directory.  Directory 7016176690 exists.
# Error making directory.  Directory 7016176812 exists.
# Error making directory.  Directory 7016178440 exists.
# Error making directory.  Directory 7016179882 exists.
# Error making directory.  Directory 7015983216 exists.
# Error making directory.  Directory 7015983482 exists.
# Error making directory.  Directory 7016042743 exists.
# Error making directory.  Directory 7016044113 exists.
# Error making directory.  Directory 7016049254 exists.
# Error making directory.  Directory 7016052040 exists.
# Error making directory.  Directory 7016062559 exists.
# Error making directory.  Directory 7016065963 exists.
# Error making directory.  Directory 7016066926 exists.
# Error making directory.  Directory 7016107272 exists.
# Error making directory.  Directory 7016138572 exists.
# Error making directory.  Directory 7016140043 exists.
# Error making directory.  Directory 7016228298 exists.
# Error making directory.  Directory 7016140144 exists.
# Error making directory.  Directory 7016186323 exists.
# Error making directory.  Directory 7016186587 exists.
# Error making directory.  Directory 7016187859 exists.
# Error making directory.  Directory 7016188009 exists.
# Error making directory.  Directory 7016189312 exists.
# Error making directory.  Directory 7016239228 exists.
# Error making directory.  Directory 7016258289 exists.
# Error making directory.  Directory 7016283209 exists.
# Error making directory.  Directory 7016303628 exists.
# Error making directory.  Directory 7016306188 exists.
# Error making directory.  Directory 7015940387 exists.
# Error making directory.  Directory 7015409944 exists.
# Error making directory.  Directory 7015415980 exists.
# Error making directory.  Directory 7015430295 exists.
# Error making directory.  Directory 7014497254 exists.
# Error making directory.  Directory 7014500289 exists.
# Error making directory.  Directory 7014508205 exists.
# Error making directory.  Directory 7014526379 exists.
# Error making directory.  Directory 7014670886 exists.
# Error making directory.  Directory 7014640577 exists.
# Error making directory.  Directory 7014641533 exists.
# Error making directory.  Directory 7014643083 exists.
# Error making directory.  Directory 7014590092 exists.
# Error making directory.  Directory 7014640661 exists.
# Error making directory.  Directory 7014608746 exists.
# Error making directory.  Directory 7014640762 exists.
# Error making directory.  Directory 7014687059 exists.
# Error making directory.  Directory 7014693611 exists.
# Error making directory.  Directory 7014697824 exists.
# Error making directory.  Directory 7014711045 exists.
# Error making directory.  Directory 7014727797 exists.
# Error making directory.  Directory 7014741611 exists.
# Error making directory.  Directory 7014748521 exists.
# Error making directory.  Directory 7014759233 exists.
# Error making directory.  Directory 7014753661 exists.
# Error making directory.  Directory 7014769054 exists.
# Error making directory.  Directory 7014005805 exists.
# Error making directory.  Directory 7014005509 exists.
# Error making directory.  Directory 7014011391 exists.
# Error making directory.  Directory 7014011584 exists.
# Error making directory.  Directory 7013565376 exists.
# Error making directory.  Directory 7013166478 exists.
# Error making directory.  Directory 7013226194 exists.
# Error making directory.  Directory 7013226400 exists.
# Error making directory.  Directory 7013226234 exists.
# Error making directory.  Directory 7013233524 exists.
# Error making directory.  Directory 7013236101 exists.
# Error making directory.  Directory 7013236306 exists.
# Error making directory.  Directory 7013236486 exists.
# Error making directory.  Directory 7013265417 exists.
# Error making directory.  Directory 7013284196 exists.
# Error making directory.  Directory 7013294178 exists.
# Error making directory.  Directory 7013292211 exists.
# Error making directory.  Directory 7013297029 exists.
# Error making directory.  Directory 7013302923 exists.
# Error making directory.  Directory 7013304776 exists.
# Error making directory.  Directory 7013327871 exists.
# Error making directory.  Directory 7013327895 exists.
# Error making directory.  Directory 7013347233 exists.
# Error making directory.  Directory 7013354658 exists.
# Error making directory.  Directory 7013372553 exists.
# Error making directory.  Directory 7013380531 exists.
# Error making directory.  Directory 7013408598 exists.
# Error making directory.  Directory 7013437750 exists.
# Error making directory.  Directory 7013438839 exists.
# Error making directory.  Directory 7013441308 exists.
# Error making directory.  Directory 7012166961 exists.
# Error making directory.  Directory 7012170922 exists.
# Error making directory.  Directory 7011696176 exists.
# Error making directory.  Directory 7011696384 exists.
# Error making directory.  Directory 7011696726 exists.
# Error making directory.  Directory 7011697072 exists.
# Error making directory.  Directory 7011697558 exists.
# Error making directory.  Directory 7011473965 exists.
# Error making directory.  Directory 7011477801 exists.
# Error making directory.  Directory 7011480294 exists.
# Error making directory.  Directory 7011480615 exists.
# Error making directory.  Directory 7011523407 exists.
# Error making directory.  Directory 7011561258 exists.
# Error making directory.  Directory 7011579423 exists.
# Error making directory.  Directory 7011589522 exists.
# Error making directory.  Directory 7011609826 exists.
# Error making directory.  Directory 7011553949 exists.
# Error making directory.  Directory 7011567228 exists.
# Error making directory.  Directory 7011610773 exists.
# Error making directory.  Directory 7011639262 exists.
# Error making directory.  Directory 7011670810 exists.
# Error making directory.  Directory 7011671298 exists.
# Error making directory.  Directory 7011671326 exists.
# Error making directory.  Directory 7011671332 exists.
# Error making directory.  Directory 7011652560 exists.
# Error making directory.  Directory 7011670726 exists.
# Error making directory.  Directory 7011670748 exists.
# Error making directory.  Directory 7011671364 exists.
# Error making directory.  Directory 7011676601 exists.
# Error making directory.  Directory 7010969164 exists.
# Error making directory.  Directory 7011676622 exists.
# Error making directory.  Directory 7011021829 exists.
# Error making directory.  Directory 7011116007 exists.
# Error making directory.  Directory 7010287023 exists.
# Error making directory.  Directory 7010317082 exists.
# Error making directory.  Directory 7010320049 exists.
# Error making directory.  Directory 7010323260 exists.
# Error making directory.  Directory 7010333523 exists.
# Error making directory.  Directory 7010333823 exists.
# Error making directory.  Directory 7009637753 exists.
# Error making directory.  Directory 7009646064 exists.
# Error making directory.  Directory 7009717623 exists.
# Error making directory.  Directory 7009732398 exists.
# Error making directory.  Directory 7009737648 exists.
# Error making directory.  Directory 7009855427 exists.
# Error making directory.  Directory 7009776248 exists.
# Error making directory.  Directory 7009785144 exists.
# Error making directory.  Directory 7009963308 exists.
# Error making directory.  Directory 7009950374 exists.
# Error making directory.  Directory 7009963299 exists.
# Error making directory.  Directory 7010001583 exists.
# Error making directory.  Directory 7010001351 exists.
# Error making directory.  Directory 7010003938 exists.
# Error making directory.  Directory 7008322163 exists.
# Error making directory.  Directory 7008343016 exists.
# Error making directory.  Directory 7008379447 exists.
# Error making directory.  Directory 7008391091 exists.
# Error making directory.  Directory 7008410172 exists.
# Error making directory.  Directory 7007714360 exists.
# Error making directory.  Directory 7007748693 exists.
# Error making directory.  Directory 7007817160 exists.
# Error making directory.  Directory 7007829825 exists.
# Error making directory.  Directory 7007849359 exists.
# Error making directory.  Directory 7007938997 exists.
# Error making directory.  Directory 7007997407 exists.
# Error making directory.  Directory 7007997833 exists.
# Error making directory.  Directory 7007997942 exists.
# Error making directory.  Directory 7007999223 exists.
# Error making directory.  Directory 7007999039 exists.
# Error making directory.  Directory 7007997691 exists.
# Error making directory.  Directory 7007999129 exists.
# Error making directory.  Directory 7007999266 exists.
# Error making directory.  Directory 7008074789 exists.
# Error making directory.  Directory 7008094100 exists.
# Error making directory.  Directory 7008054623 exists.
# Error making directory.  Directory 7007187214 exists.
# Error making directory.  Directory 7007164344 exists.
# Error making directory.  Directory 7006743233 exists.
# Error making directory.  Directory 7006289042 exists.
# Error making directory.  Directory 7006314236 exists.
# Error making directory.  Directory 7006317538 exists.
# Error making directory.  Directory 7006291992 exists.
# Error making directory.  Directory 7006346398 exists.
# Error making directory.  Directory 7006346420 exists.
# Error making directory.  Directory 7006363658 exists.
# Error making directory.  Directory 7006374983 exists.
# Error making directory.  Directory 7006456368 exists.
# Error making directory.  Directory 7006456581 exists.
# Error making directory.  Directory 7006461571 exists.
# Error making directory.  Directory 7006474404 exists.
# Error making directory.  Directory 7006471118 exists.
# Error making directory.  Directory 7006551319 exists.
# Error making directory.  Directory 7006467637 exists.
# Error making directory.  Directory 7006611159 exists.
# Error making directory.  Directory 7006611189 exists.
# Error making directory.  Directory 7005243977 exists.
# Error making directory.  Directory 7005244024 exists.
# Error making directory.  Directory 7005756367 exists.
# Error making directory.  Directory 7005816797 exists.
# Error making directory.  Directory 7005244217 exists.
# Error making directory.  Directory 7005953018 exists.
# Error making directory.  Directory 7004771631 exists.
# Error making directory.  Directory 7004785143 exists.
# Error making directory.  Directory 7004785555 exists.
# Error making directory.  Directory 7004786998 exists.
# Error making directory.  Directory 7004786926 exists.
# Error making directory.  Directory 7004788082 exists.
# Error making directory.  Directory 7004787302 exists.
# Error making directory.  Directory 7004787249 exists.
# Error making directory.  Directory 7004861537 exists.
# Error making directory.  Directory 7004845291 exists.
# Error making directory.  Directory 7004869488 exists.
# Error making directory.  Directory 7004882528 exists.
# Error making directory.  Directory 7004870476 exists.
# Error making directory.  Directory 7004884907 exists.
# Error making directory.  Directory 7004887139 exists.
# Error making directory.  Directory 7004891437 exists.
# Error making directory.  Directory 7004894075 exists.
# Error making directory.  Directory 7005014356 exists.
# Error making directory.  Directory 7005051927 exists.
# Error making directory.  Directory 7005073977 exists.
# Error making directory.  Directory 7003794575 exists.
# Error making directory.  Directory 7003882550 exists.
# Error making directory.  Directory 7003886871 exists.
# Error making directory.  Directory 7003886907 exists.
# Error making directory.  Directory 7003031920 exists.
# Error making directory.  Directory 7003200633 exists.
# Error making directory.  Directory 7003251758 exists.
# Error making directory.  Directory 7003249078 exists.
# Error making directory.  Directory 7003252671 exists.
# Error making directory.  Directory 7003293506 exists.
# Error making directory.  Directory 7003413735 exists.
# Error making directory.  Directory 7003487305 exists.
# Error making directory.  Directory 7003576477 exists.
# Error making directory.  Directory 7003544016 exists.
# Error making directory.  Directory 7003591052 exists.
# Error making directory.  Directory 7003749424 exists.
# Error making directory.  Directory 7002761551 exists.
# Error making directory.  Directory 7003648708 exists.
# Error making directory.  Directory 7003693458 exists.
# Error making directory.  Directory 7003693462 exists.
# Error making directory.  Directory 7003733952 exists.
# Error making directory.  Directory 7002575103 exists.
# Error making directory.  Directory 7002620451 exists.
# Error making directory.  Directory 7002624753 exists.
# Error making directory.  Directory 7002636009 exists.
# Error making directory.  Directory 7002635887 exists.
# Error making directory.  Directory 7002574665 exists.
# Error making directory.  Directory 7002636195 exists.
# Error making directory.  Directory 7002661940 exists.
# Error making directory.  Directory 7002669061 exists.
# Error making directory.  Directory 7002695983 exists.
# Error making directory.  Directory 7002698796 exists.
# Error making directory.  Directory 7002699445 exists.
# Error making directory.  Directory 7002700525 exists.
# Error making directory.  Directory 7002707028 exists.
# Error making directory.  Directory 7002704219 exists.
# Error making directory.  Directory 7002742018 exists.
# Error making directory.  Directory 7002745204 exists.
# Error making directory.  Directory 7002745510 exists.
# Error making directory.  Directory 7002792492 exists.
# Error making directory.  Directory 7002853309 exists.
# Error making directory.  Directory 7002797713 exists.
# Error making directory.  Directory 7002913933 exists.
# Error making directory.  Directory 7002810266 exists.
# Error making directory.  Directory 7002980141 exists.
# Error making directory.  Directory 7002987253 exists.
# Error making directory.  Directory 7003753677 exists.
# Error making directory.  Directory 7003792232 exists.
# Error making directory.  Directory 7003887010 exists.
# Error making directory.  Directory 7003887188 exists.
# Error making directory.  Directory 7003906695 exists.
# Error making directory.  Directory 7003932678 exists.
# Error making directory.  Directory 7003932960 exists.
# Error making directory.  Directory 7004024777 exists.
# Error making directory.  Directory 7004032806 exists.
# Error making directory.  Directory 7004051605 exists.
# Error making directory.  Directory 7004060042 exists.
# Error making directory.  Directory 7004068312 exists.
# Error making directory.  Directory 7004070307 exists.
# Error making directory.  Directory 7004126826 exists.
# Error making directory.  Directory 7004126856 exists.
# Error making directory.  Directory 7004185012 exists.
# Error making directory.  Directory 7004193186 exists.
# Error making directory.  Directory 7004205739 exists.
# Error making directory.  Directory 7004206637 exists.
# Error making directory.  Directory 7004206647 exists.
# Error making directory.  Directory 7004214220 exists.
# Error making directory.  Directory 7004279753 exists.
# Error making directory.  Directory 7004286333 exists.
# Error making directory.  Directory 7004347780 exists.
# Error making directory.  Directory 7004347981 exists.
# Error making directory.  Directory 7004350776 exists.
# Error making directory.  Directory 7004388578 exists.
# Error making directory.  Directory 7004400958 exists.
# Error making directory.  Directory 7004347891 exists.
# Error making directory.  Directory 7004348105 exists.
# Error making directory.  Directory 7004348342 exists.
# Error making directory.  Directory 7004404831 exists.
# Error making directory.  Directory 7004550276 exists.
# Error making directory.  Directory 7004416956 exists.
# Error making directory.  Directory 7004583059 exists.
# Error making directory.  Directory 7004606730 exists.
# Error making directory.  Directory 7004438755 exists.
# Error making directory.  Directory 7004607027 exists.
# Error making directory.  Directory 7004512698 exists.
# Error making directory.  Directory 7004607457 exists.
# Error making directory.  Directory 7004607705 exists.
# Error making directory.  Directory 7004608406 exists.
# Error making directory.  Directory 7004608932 exists.
# Error making directory.  Directory 7004609685 exists.
# Error making directory.  Directory 7004610201 exists.
# Error making directory.  Directory 7004610672 exists.
# Error making directory.  Directory 7004611229 exists.
# Error making directory.  Directory 7004611448 exists.
# Error making directory.  Directory 7004611940 exists.
# Error making directory.  Directory 7004612439 exists.
# Error making directory.  Directory 7004613031 exists.
# Error making directory.  Directory 7004613588 exists.
# Error making directory.  Directory 7004623372 exists.
# Error making directory.  Directory 7004631399 exists.
# Error making directory.  Directory 7004635732 exists.
# Error making directory.  Directory 7004668242 exists.
# Error making directory.  Directory 7004686801 exists.
# Error making directory.  Directory 7004698939 exists.
# Error making directory.  Directory 7004701159 exists.
# Error making directory.  Directory 7004701969 exists.
# Error making directory.  Directory 7004704326 exists.
# Error making directory.  Directory 7004705217 exists.
# Error making directory.  Directory 7004705568 exists.
# Error making directory.  Directory 7004706247 exists.
# Error making directory.  Directory 7004746662 exists.
# Error making directory.  Directory 7004746681 exists.
# Error making directory.  Directory 7004760735 exists.
# Error making directory.  Directory 7005074043 exists.
# Error making directory.  Directory 7005081917 exists.
# Error making directory.  Directory 7005097015 exists.
# Error making directory.  Directory 7005101873 exists.
# Error making directory.  Directory 7005106219 exists.
# Error making directory.  Directory 7005119578 exists.
# Error making directory.  Directory 7005193440 exists.
# Error making directory.  Directory 7005195745 exists.
# Error making directory.  Directory 7005309087 exists.
# Error making directory.  Directory 7005241657 exists.
# Error making directory.  Directory 7005284341 exists.
# Error making directory.  Directory 7005310172 exists.
# Error making directory.  Directory 7005374978 exists.
# Error making directory.  Directory 7005363932 exists.
# Error making directory.  Directory 7005351802 exists.
# Error making directory.  Directory 7005362917 exists.
# Error making directory.  Directory 7005386926 exists.
# Error making directory.  Directory 7005420243 exists.
# Error making directory.  Directory 7005467470 exists.
# Error making directory.  Directory 7005467476 exists.
# Error making directory.  Directory 7005470866 exists.
# Error making directory.  Directory 7005564878 exists.
# Error making directory.  Directory 7005629069 exists.
# Error making directory.  Directory 7005571030 exists.
# Error making directory.  Directory 7005592253 exists.
# Error making directory.  Directory 7005629054 exists.
# Error making directory.  Directory 7005629116 exists.
# Error making directory.  Directory 7005643238 exists.
# Error making directory.  Directory 7005728292 exists.
# Error making directory.  Directory 7005735073 exists.
# Error making directory.  Directory 7005719171 exists.
# Error making directory.  Directory 7005974151 exists.
# Error making directory.  Directory 7005971775 exists.
# Error making directory.  Directory 7005975814 exists.
# Error making directory.  Directory 7005975856 exists.
# Error making directory.  Directory 7005976238 exists.
# Error making directory.  Directory 7005975996 exists.
# Error making directory.  Directory 7005996786 exists.
# Error making directory.  Directory 7006011986 exists.
# Error making directory.  Directory 7006031115 exists.
# Error making directory.  Directory 7006044983 exists.
# Error making directory.  Directory 7006047093 exists.
# Error making directory.  Directory 7006048021 exists.
# Error making directory.  Directory 7006061725 exists.
# Error making directory.  Directory 7006068998 exists.
# Error making directory.  Directory 7006080836 exists.
# Error making directory.  Directory 7006087329 exists.
# Error making directory.  Directory 7006092787 exists.
# Error making directory.  Directory 7006102434 exists.
# Error making directory.  Directory 7006107404 exists.
# Error making directory.  Directory 7006113538 exists.
# Error making directory.  Directory 7006143132 exists.
# Error making directory.  Directory 7006162115 exists.
# Error making directory.  Directory 7006163068 exists.
# Error making directory.  Directory 7006199088 exists.
# Error making directory.  Directory 7006212489 exists.
# Error making directory.  Directory 7006278059 exists.
# Error making directory.  Directory 7006618142 exists.
# Error making directory.  Directory 7006628624 exists.
# Error making directory.  Directory 7006640723 exists.
# Error making directory.  Directory 7006666448 exists.
# Error making directory.  Directory 7006673765 exists.
# Error making directory.  Directory 7006681590 exists.
# Error making directory.  Directory 7006697239 exists.
# Error making directory.  Directory 7006673737 exists.
# Error making directory.  Directory 7006673932 exists.
# Error making directory.  Directory 7006697761 exists.
# Error making directory.  Directory 7006681352 exists.
# Error making directory.  Directory 7006723920 exists.
# Error making directory.  Directory 7006726011 exists.
# Error making directory.  Directory 7006727637 exists.
# Error making directory.  Directory 7006756006 exists.
# Error making directory.  Directory 7006779505 exists.
# Error making directory.  Directory 7006786826 exists.
# Error making directory.  Directory 7006817323 exists.
# Error making directory.  Directory 7006823240 exists.
# Error making directory.  Directory 7006826702 exists.
# Error making directory.  Directory 7006829415 exists.
# Error making directory.  Directory 7006894024 exists.
# Error making directory.  Directory 7006897940 exists.
# Error making directory.  Directory 7006902290 exists.
# Error making directory.  Directory 7006917498 exists.
# Error making directory.  Directory 7006994479 exists.
# Error making directory.  Directory 7006995044 exists.
# Error making directory.  Directory 7006999663 exists.
# Error making directory.  Directory 7007014306 exists.
# Error making directory.  Directory 7007015677 exists.
# Error making directory.  Directory 7007017257 exists.
# Error making directory.  Directory 7007081192 exists.
# Error making directory.  Directory 7007038690 exists.
# Error making directory.  Directory 7007125561 exists.
# Error making directory.  Directory 7007125893 exists.
# Error making directory.  Directory 7007126236 exists.
# Error making directory.  Directory 7007126446 exists.
# Error making directory.  Directory 7007134040 exists.
# Error making directory.  Directory 7007157040 exists.
# Error making directory.  Directory 7007158523 exists.
# Error making directory.  Directory 7007286852 exists.
# Error making directory.  Directory 7007287061 exists.
# Error making directory.  Directory 7007378337 exists.
# Error making directory.  Directory 7007307119 exists.
# Error making directory.  Directory 7007378517 exists.
# Error making directory.  Directory 7007378909 exists.
# Error making directory.  Directory 7007380139 exists.
# Error making directory.  Directory 7007386476 exists.
# Error making directory.  Directory 7007445475 exists.
# Error making directory.  Directory 7007477109 exists.
# Error making directory.  Directory 7007483670 exists.
# Error making directory.  Directory 7007446956 exists.
# Error making directory.  Directory 7007477040 exists.
# Error making directory.  Directory 7007502956 exists.
# Error making directory.  Directory 7007506869 exists.
# Error making directory.  Directory 7007512116 exists.
# Error making directory.  Directory 7007568877 exists.
# Error making directory.  Directory 7007664979 exists.
# Error making directory.  Directory 7007666434 exists.
# Error making directory.  Directory 7008277280 exists.
# Error making directory.  Directory 7008296661 exists.
# Error making directory.  Directory 7008435828 exists.
# Error making directory.  Directory 7008463187 exists.
# Error making directory.  Directory 7008502600 exists.
# Error making directory.  Directory 7008573112 exists.
# Error making directory.  Directory 7008573940 exists.
# Error making directory.  Directory 7008575825 exists.
# Error making directory.  Directory 7008612651 exists.
# Error making directory.  Directory 7008617251 exists.
# Error making directory.  Directory 7008621096 exists.
# Error making directory.  Directory 7008651329 exists.
# Error making directory.  Directory 7008656821 exists.
# Error making directory.  Directory 7008677774 exists.
# Error making directory.  Directory 7008684619 exists.
# Error making directory.  Directory 7008690515 exists.
# Error making directory.  Directory 7008693143 exists.
# Error making directory.  Directory 7008718072 exists.
# Error making directory.  Directory 7008723843 exists.
# Error making directory.  Directory 7008751618 exists.
# Error making directory.  Directory 7008773851 exists.
# Error making directory.  Directory 7008793764 exists.
# Error making directory.  Directory 7008848510 exists.
# Error making directory.  Directory 7008856944 exists.
# Error making directory.  Directory 7008879308 exists.
# Error making directory.  Directory 7008882187 exists.
# Error making directory.  Directory 7008882195 exists.
# Error making directory.  Directory 7008917391 exists.
# Error making directory.  Directory 7008923169 exists.
# Error making directory.  Directory 7009051632 exists.
# Error making directory.  Directory 7009053158 exists.
# Error making directory.  Directory 7009053333 exists.
# Error making directory.  Directory 7009095131 exists.
# Error making directory.  Directory 7009078186 exists.
# Error making directory.  Directory 7009138151 exists.
# Error making directory.  Directory 7009137973 exists.
# Error making directory.  Directory 7009138159 exists.
# Error making directory.  Directory 7009141893 exists.
# Error making directory.  Directory 7009220692 exists.
# Error making directory.  Directory 7009231199 exists.
# Error making directory.  Directory 7009297508 exists.
# Error making directory.  Directory 7009243612 exists.
# Error making directory.  Directory 7009317601 exists.
# Error making directory.  Directory 7009329032 exists.
# Error making directory.  Directory 7009341572 exists.
# Error making directory.  Directory 7009341602 exists.
# Error making directory.  Directory 7009341586 exists.
# Error making directory.  Directory 7009341615 exists.
# Error making directory.  Directory 7009343009 exists.
# Error making directory.  Directory 7009325293 exists.
# Error making directory.  Directory 7009399138 exists.
# Error making directory.  Directory 7009447639 exists.
# Error making directory.  Directory 7009448383 exists.
# Error making directory.  Directory 7009448476 exists.
# Error making directory.  Directory 7009457447 exists.
# Error making directory.  Directory 7009503402 exists.
# Error making directory.  Directory 7009505318 exists.
# Error making directory.  Directory 7009525863 exists.
# Error making directory.  Directory 7010074265 exists.
# Error making directory.  Directory 7009585320 exists.
# Error making directory.  Directory 7010004703 exists.
# Error making directory.  Directory 7010011484 exists.
# Error making directory.  Directory 7010071181 exists.
# Error making directory.  Directory 7010107678 exists.
# Error making directory.  Directory 7010114915 exists.
# Error making directory.  Directory 7010146147 exists.
# Error making directory.  Directory 7010146075 exists.
# Error making directory.  Directory 7010241522 exists.
# Error making directory.  Directory 7010241563 exists.
# Error making directory.  Directory 7010278445 exists.
# Error making directory.  Directory 7010368208 exists.
# Error making directory.  Directory 7010370112 exists.
# Error making directory.  Directory 7010426329 exists.
# Error making directory.  Directory 7010556520 exists.
# Error making directory.  Directory 7010635720 exists.
# Error making directory.  Directory 7010668662 exists.
# Error making directory.  Directory 7010681622 exists.
# Error making directory.  Directory 7010684179 exists.
# Error making directory.  Directory 7010703184 exists.
# Error making directory.  Directory 7010753561 exists.
# Error making directory.  Directory 7010728916 exists.
# Error making directory.  Directory 7010822316 exists.
# Error making directory.  Directory 7010812261 exists.
# Error making directory.  Directory 7010860610 exists.
# Error making directory.  Directory 7010868518 exists.
# Error making directory.  Directory 7010869540 exists.
# Error making directory.  Directory 7010857507 exists.
# Error making directory.  Directory 7010858527 exists.
# Error making directory.  Directory 7010874377 exists.
# Error making directory.  Directory 7010877227 exists.
# Error making directory.  Directory 7010880313 exists.
# Error making directory.  Directory 7010900248 exists.
# Error making directory.  Directory 7010901778 exists.
# Error making directory.  Directory 7010952252 exists.
# Error making directory.  Directory 7010965701 exists.
# Error making directory.  Directory 7011145990 exists.
# Error making directory.  Directory 7011179486 exists.
# Error making directory.  Directory 7011219452 exists.
# Error making directory.  Directory 7011240872 exists.
# Error making directory.  Directory 7011296252 exists.
# Error making directory.  Directory 7011296447 exists.
# Error making directory.  Directory 7011297436 exists.
# Error making directory.  Directory 7011304758 exists.
# Error making directory.  Directory 7011305195 exists.
# Error making directory.  Directory 7011327785 exists.
# Error making directory.  Directory 7011333909 exists.
# Error making directory.  Directory 7011384785 exists.
# Error making directory.  Directory 7011390165 exists.
# Error making directory.  Directory 7011390521 exists.
# Error making directory.  Directory 7011390513 exists.
# Error making directory.  Directory 7011409154 exists.
# Error making directory.  Directory 7011414772 exists.
# Error making directory.  Directory 7011415810 exists.
# Error making directory.  Directory 7011415845 exists.
# Error making directory.  Directory 7011429425 exists.
# Error making directory.  Directory 7011429746 exists.
# Error making directory.  Directory 7011676617 exists.
# Error making directory.  Directory 7011676656 exists.
# Error making directory.  Directory 7011677111 exists.
# Error making directory.  Directory 7011677195 exists.
# Error making directory.  Directory 7011677496 exists.
# Error making directory.  Directory 7011695877 exists.
# Error making directory.  Directory 7011697775 exists.
# Error making directory.  Directory 7011742907 exists.
# Error making directory.  Directory 7011815101 exists.
# Error making directory.  Directory 7011818640 exists.
# Error making directory.  Directory 7011819763 exists.
# Error making directory.  Directory 7011853480 exists.
# Error making directory.  Directory 7011913842 exists.
# Error making directory.  Directory 7011922919 exists.
# Error making directory.  Directory 7011939575 exists.
# Error making directory.  Directory 7011950908 exists.
# Error making directory.  Directory 7011952924 exists.
# Error making directory.  Directory 7011984571 exists.
# Error making directory.  Directory 7011984706 exists.
# Error making directory.  Directory 7011985009 exists.
# Error making directory.  Directory 7011985156 exists.
# Error making directory.  Directory 7011985313 exists.
# Error making directory.  Directory 7011989888 exists.
# Error making directory.  Directory 7011990144 exists.
# Error making directory.  Directory 7012015393 exists.
# Error making directory.  Directory 7012024265 exists.
# Error making directory.  Directory 7012025774 exists.
# Error making directory.  Directory 7012060151 exists.
# Error making directory.  Directory 7012067588 exists.
# Error making directory.  Directory 7012048022 exists.
# Error making directory.  Directory 7012093063 exists.
# Error making directory.  Directory 7012273763 exists.
# Error making directory.  Directory 7012291176 exists.
# Error making directory.  Directory 7012324907 exists.
# Error making directory.  Directory 7012378629 exists.
# Error making directory.  Directory 7012427633 exists.
# Error making directory.  Directory 7012434156 exists.
# Error making directory.  Directory 7012434453 exists.
# Error making directory.  Directory 7012434752 exists.
# Error making directory.  Directory 7012435019 exists.
# Error making directory.  Directory 7012435213 exists.
# Error making directory.  Directory 7012435461 exists.
# Error making directory.  Directory 7012462735 exists.
# Error making directory.  Directory 7012464866 exists.
# Error making directory.  Directory 7012548410 exists.
# Error making directory.  Directory 7012622083 exists.
# Error making directory.  Directory 7012622373 exists.
# Error making directory.  Directory 7012622261 exists.
# Error making directory.  Directory 7012630478 exists.
# Error making directory.  Directory 7012630299 exists.
# Error making directory.  Directory 7012653755 exists.
# Error making directory.  Directory 7012690145 exists.
# Error making directory.  Directory 7012731203 exists.
# Error making directory.  Directory 7012752278 exists.
# Error making directory.  Directory 7012853356 exists.
# Error making directory.  Directory 7012929515 exists.
# Error making directory.  Directory 7012967058 exists.
# Error making directory.  Directory 7013042214 exists.
# Error making directory.  Directory 7013054491 exists.
# Error making directory.  Directory 7013059145 exists.
# Error making directory.  Directory 7013077962 exists.
# Error making directory.  Directory 7013496998 exists.
# Error making directory.  Directory 7013522120 exists.
# Error making directory.  Directory 7013524654 exists.
# Error making directory.  Directory 7013514095 exists.
# Error making directory.  Directory 7013586482 exists.
# Error making directory.  Directory 7013635245 exists.
# Error making directory.  Directory 7013635243 exists.
# Error making directory.  Directory 7013635244 exists.
# Error making directory.  Directory 7013635320 exists.
# Error making directory.  Directory 7013635918 exists.
# Error making directory.  Directory 7013671052 exists.
# Error making directory.  Directory 7013745400 exists.
# Error making directory.  Directory 7013749383 exists.
# Error making directory.  Directory 7013754990 exists.
# Error making directory.  Directory 7013915395 exists.
# Error making directory.  Directory 7013948793 exists.
# Error making directory.  Directory 7013949161 exists.
# Error making directory.  Directory 7013969140 exists.
# Error making directory.  Directory 7013979217 exists.
# Error making directory.  Directory 7014000159 exists.
# Error making directory.  Directory 7014000910 exists.
# Error making directory.  Directory 7014001293 exists.
# Error making directory.  Directory 7014002299 exists.
# Error making directory.  Directory 7014004149 exists.
# Error making directory.  Directory 7014004268 exists.
# Error making directory.  Directory 7014004712 exists.
# Error making directory.  Directory 7014012361 exists.
# Error making directory.  Directory 7014013104 exists.
# Error making directory.  Directory 7014041042 exists.
# Error making directory.  Directory 7014041129 exists.
# Error making directory.  Directory 7014063908 exists.
# Error making directory.  Directory 7014050094 exists.
# Error making directory.  Directory 7014095082 exists.
# Error making directory.  Directory 7014131582 exists.
# Error making directory.  Directory 7014154885 exists.
# Error making directory.  Directory 7014156433 exists.
# Error making directory.  Directory 7014159675 exists.
# Error making directory.  Directory 7014161796 exists.
# Error making directory.  Directory 7014163419 exists.
# Error making directory.  Directory 7014167113 exists.
# Error making directory.  Directory 7014231305 exists.
# Error making directory.  Directory 7014242453 exists.
# Error making directory.  Directory 7014258166 exists.
# Error making directory.  Directory 7014402721 exists.
# Error making directory.  Directory 7014427508 exists.
# Error making directory.  Directory 7014429910 exists.
# Error making directory.  Directory 7014431487 exists.
# Error making directory.  Directory 7014442497 exists.
# Error making directory.  Directory 7014462147 exists.
# Error making directory.  Directory 7014804668 exists.
# Error making directory.  Directory 7014859579 exists.
# Error making directory.  Directory 7014875132 exists.
# Error making directory.  Directory 7014876244 exists.
# Error making directory.  Directory 7014892096 exists.
# Error making directory.  Directory 7014894287 exists.
# Error making directory.  Directory 7014895806 exists.
# Error making directory.  Directory 7014897590 exists.
# Error making directory.  Directory 7014906193 exists.
# Error making directory.  Directory 7014948886 exists.
# Error making directory.  Directory 7014951278 exists.
# Error making directory.  Directory 7014960459 exists.
# Error making directory.  Directory 7014961830 exists.
# Error making directory.  Directory 7014970359 exists.
# Error making directory.  Directory 7014990426 exists.
# Error making directory.  Directory 7015003193 exists.
# Error making directory.  Directory 7015005617 exists.
# Error making directory.  Directory 7015032703 exists.
# Error making directory.  Directory 7015086867 exists.
# Error making directory.  Directory 7015041136 exists.
# Error making directory.  Directory 7015101802 exists.
# Error making directory.  Directory 7015106564 exists.
# Error making directory.  Directory 7015170771 exists.
# Error making directory.  Directory 7015194315 exists.
# Error making directory.  Directory 7015210413 exists.
# Error making directory.  Directory 7015242400 exists.
# Error making directory.  Directory 7015237455 exists.
# Error making directory.  Directory 7015263316 exists.
# Error making directory.  Directory 7015263333 exists.
# Error making directory.  Directory 7015313727 exists.
# Error making directory.  Directory 7015315333 exists.
# Error making directory.  Directory 7015263371 exists.
# Error making directory.  Directory 7015317024 exists.
# Error making directory.  Directory 7015317177 exists.
# Error making directory.  Directory 7015339996 exists.
# Error making directory.  Directory 7015430288 exists.
# Error making directory.  Directory 7015473263 exists.
# Error making directory.  Directory 7015494581 exists.
# Error making directory.  Directory 7015521554 exists.
# Error making directory.  Directory 7015541869 exists.
# Error making directory.  Directory 7015554564 exists.
# Error making directory.  Directory 7015556444 exists.
# Error making directory.  Directory 7015583789 exists.
# Error making directory.  Directory 7015595260 exists.
# Error making directory.  Directory 7015654338 exists.
# Error making directory.  Directory 7015690270 exists.
# Error making directory.  Directory 7015700253 exists.
# Error making directory.  Directory 7015726754 exists.
# Error making directory.  Directory 7015728950 exists.
# Error making directory.  Directory 7015733670 exists.
# Error making directory.  Directory 7015734008 exists.
# Error making directory.  Directory 7015736332 exists.
# Error making directory.  Directory 7015744182 exists.
# Error making directory.  Directory 7015751610 exists.
# Error making directory.  Directory 7015831079 exists.
# Error making directory.  Directory 7015848570 exists.
# Error making directory.  Directory 7015857851 exists.
# Error making directory.  Directory 7015880982 exists.
# Error making directory.  Directory 7016340885 exists.
# Error making directory.  Directory 7016358511 exists.
# Error making directory.  Directory 7016361402 exists.
# Error making directory.  Directory 7016374260 exists.
# Error making directory.  Directory 7016381143 exists.
# Error making directory.  Directory 7016381896 exists.
# Error making directory.  Directory 7016493939 exists.
# Error making directory.  Directory 7016539902 exists.
# Error making directory.  Directory 7016443108 exists.
# Error making directory.  Directory 7016496361 exists.
# Error making directory.  Directory 7016622254 exists.
# Error making directory.  Directory 7016643161 exists.
# Error making directory.  Directory 7016646695 exists.
# Error making directory.  Directory 7016651728 exists.
# Error making directory.  Directory 7016651832 exists.
# Error making directory.  Directory 7016651757 exists.
# Error making directory.  Directory 7016643496 exists.
# Error making directory.  Directory 7016671648 exists.
# Error making directory.  Directory 7016672469 exists.
# Error making directory.  Directory 7016688494 exists.
# Error making directory.  Directory 7016683138 exists.
# Error making directory.  Directory 7016692598 exists.
# Error making directory.  Directory 7016697216 exists.
# Error making directory.  Directory 7016698134 exists.
# Error making directory.  Directory 7016699136 exists.
# Error making directory.  Directory 7016699396 exists.
# Error making directory.  Directory 7016701967 exists.
# Error making directory.  Directory 7016723725 exists.
# Error making directory.  Directory 7016746486 exists.
# Error making directory.  Directory 7016748041 exists.
# Error making directory.  Directory 7016768337 exists.
# Error making directory.  Directory 7016770195 exists.
# Error making directory.  Directory 7016798988 exists.
# Error making directory.  Directory 7016817838 exists.
# Error making directory.  Directory 7016821122 exists.
# Error making directory.  Directory 7016824229 exists.
# Error making directory.  Directory 7016803089 exists.
# Error making directory.  Directory 7016831644 exists.
# Error making directory.  Directory 7016846109 exists.
# Error making directory.  Directory 7016834440 exists.
# Error making directory.  Directory 7016905378 exists.
# Error making directory.  Directory 7016849062 exists.
# Error making directory.  Directory 7016919135 exists.
# Error making directory.  Directory 7016957658 exists.
# Error making directory.  Directory 7017246670 exists.
# Error making directory.  Directory 7016915111 exists.
# Error making directory.  Directory 7016915119 exists.
# Error making directory.  Directory 7017246789 exists.
# Error making directory.  Directory 7017246585 exists.
# Error making directory.  Directory 7017254342 exists.
# Error making directory.  Directory 7017254137 exists.
# Error making directory.  Directory 7017254457 exists.
# Error making directory.  Directory 7017275909 exists.
# Error making directory.  Directory 7017282798 exists.
# Error making directory.  Directory 7017720793 exists.
# ...
# Error making directory.  Directory 7018162760 exists.
# Error making directory.  Directory 7018169956 exists.
# Error making directory.  Directory 7018195582 exists.
# Error making directory.  Directory 7018217468 exists.
# Error making directory.  Directory 7018227344 exists.
# Error making directory.  Directory 7018231935 exists.
# Error making directory.  Directory 7018250312 exists.
# Error making directory.  Directory 7018250813 exists.
# Error making directory.  Directory 7018257175 exists.
# Error making directory.  Directory 7018292899 exists.
# Error making directory.  Directory 7018337079 exists.
# Error making directory.  Directory 7018337146 exists.
# Error making directory.  Directory 7018398643 exists.
# Error making directory.  Directory 7018422322 exists.
# Error making directory.  Directory 7018425711 exists.
# Error making directory.  Directory 7018450379 exists.
# Error making directory.  Directory 7018490460 exists.
# Error making directory.  Directory 7018490648 exists.
# Error making directory.  Directory 7018490523 exists.
# Error making directory.  Directory 7018491494 exists.
# Error making directory.  Directory 7018497709 exists.
# Error making directory.  Directory 7018498140 exists.
# Error making directory.  Directory 7018501631 exists.
# Error making directory.  Directory 7018524124 exists.
# Error making directory.  Directory 7018531141 exists.
# Error making directory.  Directory 7018574830 exists.
# Error making directory.  Directory 7018576727 exists.
# Error making directory.  Directory 7018585771 exists.
# Error making directory.  Directory 7018621008 exists.
# Error making directory.  Directory 7018624157 exists.
# Error making directory.  Directory 7018624380 exists.
# Error making directory.  Directory 7018624809 exists.
# Error making directory.  Directory 7018625026 exists.
# Error making directory.  Directory 7018625553 exists.
# Error making directory.  Directory 7018627099 exists.
# Error making directory.  Directory 7018627815 exists.
# Error making directory.  Directory 7018628038 exists.
# Error making directory.  Directory 7018629326 exists.
# Error making directory.  Directory 7018651838 exists.
# Error making directory.  Directory 7018662729 exists.
# Error making directory.  Directory 7019009042 exists.
# Error making directory.  Directory 7019113332 exists.
# Error making directory.  Directory 7019148421 exists.
# Error making directory.  Directory 7019154637 exists.
# Error making directory.  Directory 7019154766 exists.
# Error making directory.  Directory 7019156996 exists.
# Error making directory.  Directory 7019158423 exists.
# Error making directory.  Directory 7019156262 exists.
# Error making directory.  Directory 7019158620 exists.
# Error making directory.  Directory 7019158771 exists.
# Error making directory.  Directory 7019193285 exists.
# Error making directory.  Directory 7019212249 exists.
# Error making directory.  Directory 7019212380 exists.
# Error making directory.  Directory 7019213361 exists.
# Error making directory.  Directory 7019251556 exists.
# Error making directory.  Directory 7019265813 exists.
# Error making directory.  Directory 7019267094 exists.
# Error making directory.  Directory 7019268962 exists.
# Error making directory.  Directory 7019277922 exists.
# Error making directory.  Directory 7019287431 exists.
# Error making directory.  Directory 7019289677 exists.
# Error making directory.  Directory 7019289867 exists.
# Error making directory.  Directory 7019289816 exists.
# Error making directory.  Directory 7019338440 exists.
# Error making directory.  Directory 7019348066 exists.
# Error making directory.  Directory 7019384143 exists.
# Error making directory.  Directory 7019391062 exists.
# Error making directory.  Directory 7019391784 exists.
# Error making directory.  Directory 7019396455 exists.
# Error making directory.  Directory 7019398167 exists.
# Error making directory.  Directory 7019398790 exists.
# Error making directory.  Directory 7019454562 exists.
# Error making directory.  Directory 7019456717 exists.
# Error making directory.  Directory 7019493570 exists.
# Error making directory.  Directory 7019536606 exists.
# Error making directory.  Directory 7019566562 exists.
# Error making directory.  Directory 7019591740 exists.
# Error making directory.  Directory 7019647657 exists.
# Error making directory.  Directory 7019727117 exists.
# Error making directory.  Directory 7019734333 exists.
# Error making directory.  Directory 7019770906 exists.
# Error making directory.  Directory 7019810808 exists.
# Error making directory.  Directory 7019820073 exists.
# Error making directory.  Directory 7019820488 exists.
# Error making directory.  Directory 7019814560 exists.
# Error making directory.  Directory 7019822375 exists.
# Error making directory.  Directory 7019833531 exists.
# Error making directory.  Directory 7019837997 exists.
# Error making directory.  Directory 7019840380 exists.
# Error making directory.  Directory 7019850713 exists.
# Error making directory.  Directory 7019854552 exists.
# Error making directory.  Directory 7019856950 exists.
# Error making directory.  Directory 7019869918 exists.
# Error making directory.  Directory 7019884563 exists.
# Error making directory.  Directory 7019892136 exists.
# Error making directory.  Directory 7019893723 exists.
# Error making directory.  Directory 7019910194 exists.
# Error making directory.  Directory 7019941798 exists.
# Error making directory.  Directory 7019950279 exists.
# Error making directory.  Directory 7019968135 exists.
# Error making directory.  Directory 7019973494 exists.
# Error making directory.  Directory 7019990030 exists.
# Error making directory.  Directory 7019990091 exists.
# Error making directory.  Directory 7020008767 exists.
# Error making directory.  Directory 7020012626 exists.
# Error making directory.  Directory 7020403049 exists.
# Error making directory.  Directory 7020439572 exists.
# Error making directory.  Directory 7020452645 exists.
# Error making directory.  Directory 7020460238 exists.
# Error making directory.  Directory 7020461028 exists.
# Error making directory.  Directory 7020498785 exists.
# Error making directory.  Directory 7020498863 exists.
# Error making directory.  Directory 7020556334 exists.
# Error making directory.  Directory 7020557345 exists.
# Error making directory.  Directory 7020571026 exists.
# Error making directory.  Directory 7020612464 exists.
# Error making directory.  Directory 7020612847 exists.
# Error making directory.  Directory 7020631273 exists.
# Error making directory.  Directory 7020637945 exists.
# Error making directory.  Directory 7020644991 exists.
# Error making directory.  Directory 7020686158 exists.
# Error making directory.  Directory 7020706072 exists.
# Error making directory.  Directory 7020706076 exists.
# Error making directory.  Directory 7020713720 exists.
# Error making directory.  Directory 7020713898 exists.
# Error making directory.  Directory 7020610604 exists.
# Error making directory.  Directory 7020746301 exists.
# Error making directory.  Directory 7020759235 exists.
# Error making directory.  Directory 7020761340 exists.
# Error making directory.  Directory 7020769402 exists.
# Error making directory.  Directory 7020778522 exists.
# Error making directory.  Directory 7020779759 exists.
# Error making directory.  Directory 7020818529 exists.
# Error making directory.  Directory 7020822342 exists.
# Error making directory.  Directory 7020839827 exists.
# Error making directory.  Directory 7020850148 exists.
# Error making directory.  Directory 7020853945 exists.
# Error making directory.  Directory 7020854454 exists.
# Error making directory.  Directory 7020856376 exists.
# Error making directory.  Directory 7020859206 exists.
# Error making directory.  Directory 7020885312 exists.
# Error making directory.  Directory 7020931559 exists.
# Error making directory.  Directory 7020931891 exists.
# Error making directory.  Directory 7020953941 exists.
# Error making directory.  Directory 7021043084 exists.
# Error making directory.  Directory 7021048892 exists.
# Error making directory.  Directory 7021116938 exists.
# Error making directory.  Directory 7021118407 exists.
# Error making directory.  Directory 7021118474 exists.
# Error making directory.  Directory 7021120223 exists.
# Error making directory.  Directory 7021133219 exists.
# Error making directory.  Directory 7021134535 exists.
# Error making directory.  Directory 7021135877 exists.
# Error making directory.  Directory 7021140949 exists.
# Error making directory.  Directory 7021146150 exists.
# Error making directory.  Directory 7021147048 exists.
# Error making directory.  Directory 7021182654 exists.
# Error making directory.  Directory 7021206168 exists.
# Error making directory.  Directory 7021219984 exists.
# Error making directory.  Directory 7021220011 exists.
# Error making directory.  Directory 7021228782 exists.
# Error making directory.  Directory 7021241487 exists.
# Error making directory.  Directory 7021240787 exists.
# Error making directory.  Directory 7021243689 exists.
# Error making directory.  Directory 7021253255 exists.
# Error making directory.  Directory 7021274362 exists.
# Error making directory.  Directory 7021286245 exists.
# Error making directory.  Directory 7021292857 exists.
# Error making directory.  Directory 7021294831 exists.
# Error making directory.  Directory 7021311667 exists.
# Error making directory.  Directory 7021316315 exists.
# Error making directory.  Directory 7021317272 exists.
# Error making directory.  Directory 7021325790 exists.
# Error making directory.  Directory 7021857058 exists.
# Error making directory.  Directory 7021887419 exists.
# Error making directory.  Directory 7021938737 exists.
# Error making directory.  Directory 7021888167 exists.
# Error making directory.  Directory 7021967948 exists.
# Error making directory.  Directory 7022003719 exists.
# Error making directory.  Directory 7021973455 exists.
# Error making directory.  Directory 7022039260 exists.
# Error making directory.  Directory 7022074018 exists.
# Error making directory.  Directory 7022088416 exists.
# Error making directory.  Directory 7022090541 exists.
# Error making directory.  Directory 7022094980 exists.
# Error making directory.  Directory 7022098341 exists.
# Error making directory.  Directory 7022100195 exists.
# Error making directory.  Directory 7022104195 exists.
# Error making directory.  Directory 7022115765 exists.
# Error making directory.  Directory 7022230892 exists.
# Error making directory.  Directory 7022431909 exists.
# Error making directory.  Directory 7022496492 exists.
# Error making directory.  Directory 7022454324 exists.
# Error making directory.  Directory 7022477426 exists.
# Error making directory.  Directory 7022477509 exists.
# Error making directory.  Directory 7022507987 exists.
# Error making directory.  Directory 7022508312 exists.
# Error making directory.  Directory 7022508548 exists.
# Error making directory.  Directory 7022508850 exists.
# Error making directory.  Directory 7022516288 exists.
# Error making directory.  Directory 7022525722 exists.
# Error making directory.  Directory 7022561616 exists.
# Error making directory.  Directory 7022561666 exists.
# Error making directory.  Directory 7022563926 exists.
# Error making directory.  Directory 7022580450 exists.
# Error making directory.  Directory 7022582525 exists.
# Error making directory.  Directory 7022612628 exists.
# Error making directory.  Directory 7022633463 exists.
# Error making directory.  Directory 7022648534 exists.
# Error making directory.  Directory 7022652233 exists.
# Error making directory.  Directory 7022666958 exists.
# Error making directory.  Directory 7022675052 exists.
# Error making directory.  Directory 7022713616 exists.
# Error making directory.  Directory 7022687888 exists.
# Error making directory.  Directory 7022665286 exists.
# Error making directory.  Directory 7022669892 exists.
# Error making directory.  Directory 7022692371 exists.
# Error making directory.  Directory 7022690937 exists.
# Error making directory.  Directory 7022667010 exists.
# Error making directory.  Directory 7022674664 exists.
# Error making directory.  Directory 7022692732 exists.
# Error making directory.  Directory 7022669029 exists.
# Error making directory.  Directory 7022677134 exists.
# Error making directory.  Directory 7022693721 exists.
# Error making directory.  Directory 7022444470 exists.
# Error making directory.  Directory 7022447046 exists.
# Error making directory.  Directory 7022449254 exists.
# Error making directory.  Directory 7022452198 exists.
# Error making directory.  Directory 7022467703 exists.
# Error making directory.  Directory 7022472454 exists.
# Error making directory.  Directory 7022477621 exists.
# Error making directory.  Directory 7022481027 exists.
# Error making directory.  Directory 7022483361 exists.
# Error making directory.  Directory 7022506714 exists.
# Error making directory.  Directory 7022485252 exists.
# Error making directory.  Directory 7022494381 exists.
# Error making directory.  Directory 7022503239 exists.
# Error making directory.  Directory 7022503552 exists.
# Error making directory.  Directory 7022510903 exists.
# Error making directory.  Directory 7022510869 exists.
# Error making directory.  Directory 7022511673 exists.
# Error making directory.  Directory 7022513947 exists.
# Error making directory.  Directory 7022514325 exists.
# Error making directory.  Directory 7022381682 exists.
# Error making directory.  Directory 7022382410 exists.
# Error making directory.  Directory 7022231130 exists.
# Error making directory.  Directory 7022234109 exists.
# Error making directory.  Directory 7022234508 exists.
# Error making directory.  Directory 7022236118 exists.
# Error making directory.  Directory 7022243656 exists.
# Error making directory.  Directory 7022020213 exists.
# Error making directory.  Directory 7022026941 exists.
# Error making directory.  Directory 7022075867 exists.
# Error making directory.  Directory 7022080892 exists.
# Error making directory.  Directory 7022086899 exists.
# Error making directory.  Directory 7022050154 exists.
# Error making directory.  Directory 7022105172 exists.
# Error making directory.  Directory 7022112793 exists.
# Error making directory.  Directory 7022127597 exists.
# Error making directory.  Directory 7022131459 exists.
# Error making directory.  Directory 7022134235 exists.
# Error making directory.  Directory 7022141912 exists.
# Error making directory.  Directory 7022161324 exists.
# Error making directory.  Directory 7022168140 exists.
# Error making directory.  Directory 7022010851 exists.
# Error making directory.  Directory 7021742016 exists.
# Error making directory.  Directory 7021746353 exists.
# Error making directory.  Directory 7021763549 exists.
# Error making directory.  Directory 7021771939 exists.
# Error making directory.  Directory 7021534947 exists.
# Error making directory.  Directory 7021759570 exists.
# Error making directory.  Directory 7021495594 exists.
# Error making directory.  Directory 7021476193 exists.
# Error making directory.  Directory 7021478046 exists.
# Error making directory.  Directory 7021495886 exists.
# Error making directory.  Directory 7021490479 exists.
# Error making directory.  Directory 7021493060 exists.
# Error making directory.  Directory 7021510137 exists.
# Error making directory.  Directory 7021513905 exists.
# Sleeping...  Current imCount: 450
# Non-timeout error. 7021246115 00s0s_8eL1wC819zh_600x450
# Non-timeout error. 7021271652 00909_cDDunpKdPGE_600x450
# Sleeping...  Current imCount: 900
# Non-timeout error. 7020934080 00v0v_irp8Ij11D6q_600x450
# Sleeping...  Current imCount: 1350
# Non-timeout error. 7020989656 01111_hNDjJstJtza_600x450
# Sleeping...  Current imCount: 1800
# Sleeping...  Current imCount: 2250
# Non-timeout error. 7020610859 00G0G_9jwsoKpu1L7_600x450
# Sleeping...  Current imCount: 2700
# Non-timeout error. 7020615385 01212_gvxOS5ipHlI_600x450
# Non-timeout error. 7020597569 00k0k_cJHTkGtKQCV_600x450
# Sleeping...  Current imCount: 3150
# Non-timeout error. 7020608789 00W0W_9Qcwp8IFo0t_600x450
# Sleeping...  Current imCount: 3600
# Non-timeout error. 7020218993 00202_57nOP12nF1V_600x450
# Non-timeout error. 7020009586 00g0g_kn2nnZI62bs_600x450
# Sleeping...  Current imCount: 4050
# Non-timeout error. 7020107121 00E0E_21oSvaO5U4e_600x450

# %%
# count=0
# for idx in vehicle.index:
#     count+=len(vehicle.loc[idx, 'ImageDictionary'])
# count

# %%
# 126617/6990

# %%
# count = 0
# for i in range(0,52):
#     print(count)
#     count += 1
#     if count % 10 == 0:
#         sleep_sec = np.random.randint(low=5, high=12)
#         time.sleep(sleep_sec)
#         print('time slept:', sleep_sec)

# %%
# imConverted = Image.open(f'Z:\DATA_SCIENCE\car_images\{imFName}')
# print('imConverted format:', imConverted.format_description, '\nimConvertedage mode:', imConverted.mode, '\nimConverted size:', imConverted.size)

# %%
# #Open image from URL. Save as PNG.
# URL = 'https://images.craigslist.org/00t0t_79tmoKPwmNV_600x450.jpg'
# im = Image.open(requests.get(URL, stream=True).raw)
# imFName = re.search('org/(\S+)\.jpg', URL).group(1) + '.png' #re.search(pattern, string) gets first match
# im.save(f'Z:\DATA_SCIENCE\car_images\{imFName}', format='PNG')

# %%
# myurl = 'https://images.craigslist.org/00t0t_79tmoKPwmNV_600x450.jpg'
# im = Image.open(urllib.request.urlopen(myurl))
